# %%
import serial
import time
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ser = serial.Serial()

# %%
ser.baudrate = 9600 
ser.port = 'COM5' 
#ser.parity=serial.PARITY_EVEN

ser.timeout=2
print ser.name
print ser
ser.open()
ser.is_open
# Out:
# COM5
# Serial<id=0x3944050, open=False>(port='COM5', baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=2, xonxoff=False, rtscts=False, dsrdtr=False)
# True

# %%
for i in range (100) :
    time.sleep(0.1)
    print ser.readline()
# Out:
# AIN0: 52	Voltage: 0.0098130
#
#
#
# AIN0: 52	Voltage: 0.0098218
#
#
#
# AIN0: 52	Voltage: 0.0097925
#
#
#
# AIN0: 52	Voltage: 0.0098159
#
#
#
# AIN0: 52	Voltage: 0.0098979
#
#
#
# AIN0: 52	Voltage: 0.0098511
#
#
#
# AIN0: 52	Voltage: 0.0099170
#
#
#
# AIN0: 52	Voltage: 0.0098423
#
#
#
# AIN0: 52	Voltage: 0.0098701
#
#
#
# AIN0: 52	Voltage: 0.0099170
#
#
#
# AIN0: 52	Voltage: 0.0098481
#
#
#
# AIN0: 52	Voltage: 0.0098730
#
#
#
# AIN0: 50	Voltage: 0.0094614
#
#
#
# AIN0: 50	Voltage: 0.0093896
#
#
#
# AIN0: 53	Voltage: 0.0099492
#
#
#
# AIN0: 52	Voltage: 0.0099023
#
#
#
# AIN0: 2962	Voltage: 0.5554600
#
#
#
# AIN0: 4749	Voltage: 0.8905459
#
#
#
# AIN0: 4744	Voltage: 0.8896362
#
#
#
# AIN0: 4730	Voltage: 0.8869263
#
#
#
# AIN0: 4767	Voltage: 0.8938609
#
#
#
# AIN0: 4776	Voltage: 0.8955923
#
#
#
# AIN0: 4761	Voltage: 0.8928003
#
#
#
# AIN0: 4748	Voltage: 0.8902706
#
#
#
# AIN0: 4423	Voltage: 0.8293286
#
#
#
# AIN0: 3443	Voltage: 0.6455947
#
#
#
# AIN0: 3436	Voltage: 0.6443614
#
#
#
# ...
